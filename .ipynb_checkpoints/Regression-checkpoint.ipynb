# 36  -18932.355725  493.685371  291.898792  4395.919743  2021.100000
# 37  -28767.543592  519.478031  273.257352  4197.412871  2017.900000
# 38  -48795.130431  496.584039  301.996440  4437.428171  2007.700000
# 39  -17293.437462  451.339717  273.084692  4154.417957  1974.300000
# 40  -32035.560642  445.941500  284.354548  4495.322171  2052.700000
# 41  -43106.882920  465.699855  288.742638  4500.977957  2042.700000
# 42  -72828.840582  494.770710  302.147611  4528.628443  1983.800000
# 43  -61798.226328  561.582998  293.288778  4353.562843  2064.800000
# 44  -80152.143632  527.762441  289.705029  4466.923543  2071.800000
# 45  -43801.331360  450.245444  252.585390  3708.758871  1940.200000
# 46  -43144.977771  437.412319  267.640929  4216.634086  2005.400000
#
#        capacity
# 0   2288.498556
# 1   2305.934889
# 2   2308.251583
# 3   2320.224250
# 4   2216.700000
# 5   2248.300000
# 6   2260.000000
# 7   2262.000000
# 8   2277.000000
# 9   2246.400000
# 10  2270.300000
# 11  2206.300000
# 12  2331.591028
# 13  2295.616028
# 14  2332.193722
# 15  2310.483528
# 16  2258.200000
# 17  2261.100000
# 18  2322.700528
# 19  2336.715639
# 20  2325.186028
# 21  2059.400000
# 22  2264.600000
# 23  2191.800000
# 24  2334.500000
# 25  2281.208528
# 26  2337.931306
# 27  2339.388611
# 28  2207.500000
# 29  2250.900000
# 30  2257.500000
# 31  2258.900000
# 32  2262.400000
# 33  2271.500000
# 34  2243.700000
# 35  2202.000000
# 36  2259.100000
# 37  2238.300000
# 38  2259.000000
# 39  2219.800000
# 40  2246.500000
# 41  2249.600000
# 42  2219.200000
# 43  2278.700000
# 44  2286.000000
# 45  2172.100000
# 46  2233.100000

# %%
# copy the data
data = database.__deepcopy__()
#data.drop(['ic_capacity', 'capacity'],axis=1,inplace=True)

X=data.drop(['ic_capacity', 'capacity'],axis=1).values
y= data['capacity'].values.reshape(-1,1)

sc=StandardScaler()
Scaled_data=sc.fit_transform(X)

# %%
# Set the n_components=3
principal=PCA(n_components=2)
principal.fit(Scaled_data)
pca=principal.transform(Scaled_data)

# %%
# check how much variance is explained by each principal component
print(principal.explained_variance_ratio_)
# Out:
# [0.50407028 0.30080016]

# %%
X= pca
y= database['capacity'].values.reshape(-1,1)
print(X.shape)
print(y.shape)
# Out:
# (47, 2)
# (47, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=33)

X_train = torch.FloatTensor(X_train)
X_test = torch.FloatTensor(X_test)
y_train = torch.FloatTensor(y_train)
y_test = torch.FloatTensor(y_test)

# %%
class TabularModel(nn.Module):

    def __init__(self, n_cont, out_sz, layers):
        super().__init__()
        
        self.bn_cont = nn.BatchNorm1d(n_cont)
        
        layerlist = []
        
        for i in layers:
            layerlist.append(nn.Linear(n_cont,i)) 
            layerlist.append(nn.ReLU(inplace=True))
            layerlist.append(nn.BatchNorm1d(i))
            n_cont = i
        layerlist.append(nn.Linear(layers[-1],out_sz))
            
        self.layers = nn.Sequential(*layerlist)
    
    def forward(self, x):
        
        x = self.bn_cont(x)
        x = self.layers(x)
        return x

# %%
torch.manual_seed(33)
model = TabularModel(X.shape[1], 1, [16,32,64,32,16])

# %%
criterion = nn.MSELoss()  # we'll convert this to RMSE later
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# %%
epochs = 5001
losses = []

for i in range(epochs):
    
    y_pred = model.forward(X_train)
    loss = torch.sqrt(criterion(y_pred, y_train))
    losses.append(loss.item())

# A neat trick to save screen space:
    if i%500 == 0:
        print(f'epoch: {i:2}  loss: {loss.item():10.8f}')

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# epoch:  0  loss: 2267.46215820
# epoch: 500  loss: 1245.51086426
# epoch: 1000  loss: 0.99180502
# epoch: 1500  loss: 0.36315149
# epoch: 2000  loss: 0.36077693
# epoch: 2500  loss: 0.42690378
# epoch: 3000  loss: 0.47575286
# epoch: 3500  loss: 0.50015920
# epoch: 4000  loss: 0.41772476
# epoch: 4500  loss: 0.41265622
# epoch: 5000  loss: 0.30858955

# %%
# To Evaluate the Entire Test set
# no_grad ensure that gradient is not calculated and weights and bias are not updated

with torch.no_grad():
    y_val = model.forward(X_test)
    loss = torch.sqrt(criterion(y_val , y_test))
print(f'{loss:10.8f}')
# Out:
# 45.39012527

# %%
print(f'{"PREDICTED":>12} {"ACTUAL":>8} {"DIFF":>8}')
for i in range(y_test.shape[0]):
    diff = np.abs(y_val[i].item()-y_test[i].item())
    print(f'{i+1:2}. {y_val[i].item():8.4f} {y_test[i].item():8.4f} {diff:8.4f}')
# Out:
#    PREDICTED   ACTUAL     DIFF
#  1. 2279.1018 2248.3000  30.8018
#  2. 2323.0999 2310.4836  12.6162
#  3. 2199.0891 2259.1001  60.0110
#  4. 2249.3494 2238.3000  11.0493
#  5. 2172.4478 2243.7000  71.2522
#  6. 2269.6565 2261.1001   8.5564
#  7. 2279.2893 2216.7000  62.5894
#  8. 2323.2358 2281.2085  42.0273
#  9. 2321.0852 2288.4985  32.5867
# 10. 2254.0544 2191.8000  62.2544

# %%
# MAE
mean_absolute_error(y_test, y_val)
# Out:
# 39.374462

# %%
#MSE
mean_squared_error(y_test, y_val)
# Out:
# 2060.2634

# %%
#MAPE
mean_absolute_percentage_error(y_test, y_val)
# Out:
# 0.017550306

# %%
# Max Error
max_error(y_test, y_val)
# Out:
# 71.2522

# %%
r2_score(y_test, y_val)
# Out:
# -0.9001903358249592

# %% [markdown]
# # RANDOM FOREST MODEL

# %%
#Random forest model 
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression

model = RandomForestRegressor()
model.fit(X_train,np.ravel(y_train))
# Get the mean absolute error on the validation data

y_val = model.predict(X_test)

# %%
# MAE
mean_absolute_error(y_test, y_val)
# Out:
# 21.56110205078121

# %%
#MSE
mean_squared_error(y_test, y_val)
# Out:
# 733.3677593785792

# %%
#MAPE
mean_absolute_percentage_error(y_test, y_val)
# Out:
# 0.00954432274116313

# %%
# Max Error
max_error(y_test, y_val)
# Out:
# 55.87208007812478

# %%
r2_score(y_test, y_val)
# Out:
# 0.3236116365201539

# %% [markdown]
# # XG Boost

# %%
import xgboost as xgb
XGBModel = xgb.XGBRegressor()
XGBModel.fit(X_train,np.ravel(y_train) , verbose=False)

# Get the mean absolute error on the validation data :
y_val = XGBModel.predict(X_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
# MAE
mean_absolute_error(y_test, y_val)
# Out:
# 19.709034

# %%
#MSE
mean_squared_error(y_test, y_val)
# Out:
# 731.0483

# %%
#MAPE
mean_absolute_percentage_error(y_test, y_val)
# Out:
# 0.008700091

# %%
# Max Error
max_error(y_test, y_val)
# Out:
# 54.915527

# %%
r2_score(y_test, y_val)
# Out:
# 0.32575094075740374

# %% [markdown]
# # GradientBoostingRegressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
reg = GradientBoostingRegressor(random_state=0)
reg.fit(X_train, np.ravel(y_train))
y_val=reg.predict(X_test)

# %%
# MAE
mean_absolute_error(y_test, y_val)
# Out:
# 23.020956183548606

# %%
#MSE
mean_squared_error(y_test, y_val)
# Out:
# 840.9480281165976

# %%
#MAPE
mean_absolute_percentage_error(y_test, y_val)
# Out:
# 0.010218639722137622

# %%
# Max Error
max_error(y_test, y_val)
# Out:
# 52.299508897147916

# %%
r2_score(y_test, y_val)
# Out:
# 0.22438987365442775

# %% [markdown]
# # ElasticNet

# %%
from sklearn.linear_model import ElasticNet
reg= ElasticNet(random_state=0)
reg.fit(X_train,y_train)
y_val= reg.predict(X_test)

# %%
# MAE
mean_absolute_error(y_test, y_val)
# Out:
# 19.080518161877173

# %%
#MSE
mean_squared_error(y_test, y_val)
# Out:
# 617.1462571627691

# %%
#MAPE
mean_absolute_percentage_error(y_test, y_val)
# Out:
# 0.008483924486462891

# %%
# Max Error
max_error(y_test, y_val)
# Out:
# 48.11759323241313

# %%
r2_score(y_test, y_val)
# Out:
# 0.4308032476587895

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVR
reg = SVR(kernel='rbf',degree=15)
reg.fit(X_train,np.ravel(y_train))
y_val= reg.predict(X_test)

# %%
print(f'{"PREDICTED":>12} {"ACTUAL":>8} {"DIFF":>8}')
for i in range(10):
    diff = np.abs(y_val[i].item()-y_test[i].item())
    print(f'{i+1:2}. {y_val[i].item():8.4f} {y_test[i].item():8.4f} {diff:8.4f}')
# Out:
#    PREDICTED   ACTUAL     DIFF
#  1. 2261.3195 2248.3000  13.0195
#  2. 2275.2259 2310.4836  35.2577
#  3. 2261.6008 2259.1001   2.5007
#  4. 2262.7717 2238.3000  24.4716
#  5. 2261.3544 2243.7000  17.6544
#  6. 2265.9761 2261.1001   4.8760
#  7. 2261.4967 2216.7000  44.7967
#  8. 2268.7954 2281.2085  12.4131
#  9. 2274.3724 2288.4985  14.1261
# 10. 2262.2937 2191.8000  70.4937

# %%
# MAE
mean_absolute_error(y_test, y_val)
# Out:
# 23.960945694569183

# %%
#MSE
mean_squared_error(y_test, y_val)
# Out:
# 968.2912465122488

# %%
#MAPE
mean_absolute_percentage_error(y_test, y_val)
# Out:
# 0.010710095721078224

# %%
# Max Error
max_error(y_test, y_val)
# Out:
# 70.49365884837425

# %%
r2_score(y_test, y_val)
# Out:
# 0.10694065395614627
